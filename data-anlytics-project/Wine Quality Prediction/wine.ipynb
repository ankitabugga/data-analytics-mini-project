# %% [markdown]
# # Import libararies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # load database¶

# %%
df = pd.read_csv('D:\\jn\\data-anlytics-project\\Wine Quality Prediction\\WineQT.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [raw]
# Fixed Acidity: The amount of fixed acids in the wine, which generally include tartaric, malic, citric, and lactic acids.
# Volatile Acidity: The amount of acetic acid in the wine, which can contribute to a vinegary taste if in excess.
# Citric Acid: A specific type of acid that can add a citrusy flavor to the wine.
# Residual Sugar: The amount of sugar left in the wine after fermentation, which affects sweetness.
# Chlorides: The level of chloride salts in the wine, which can impact taste and quality.
# Free Sulfur Dioxide: The amount of free (unbound) sulfur dioxide, which helps to preserve the wine and prevent spoilage.
# Total Sulfur Dioxide: The total amount of sulfur dioxide in the wine, including both free and bound forms.
# Density: The density of the wine, which can be related to its alcohol and sugar content.
# pH: The acidity level of the wine; a lower pH indicates higher acidity.
# Sulphates: The amount of sulfate compounds, which can affect taste and stability.
# Alcohol: The percentage of alcohol in the wine.
# Quality: The quality rating of the wine, typically a numeric value assigned by tasters or based on chemical characteristics.
# Id: An identifier for each record in the dataset.

# %% [markdown]
# # Basic Data Inspection

# %%
# Display the first few rows
print(df.head())

# Get summary statistics
print(df.describe())

# Check for missing values
print(df.isnull().sum())

# Data types of each column
print(df.dtypes)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %% [markdown]
# # Data Manipulation

# %%
# Adding a new column
df['new_column'] = df['fixed acidity'] * df['citric acid']
df['new_column']
# Out:
# 0       0.000
# 1       0.000
# 2       0.312
# 3       6.272
# 4       0.000
#         ...
# 1138    0.819
# 1139    0.544
# 1140    0.496
# 1141    0.590
# 1142    0.708
# Name: new_column, Length: 1143, dtype: float64

# %%
# Filtering data
high_quality_wines = df[df['quality'] > 6]
high_quality_wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 7               7.3              0.65         0.00             1.2      0.065
# 8               7.8              0.58         0.02             2.0      0.073
# 12              8.5              0.28         0.56             1.8      0.092
# 27              8.1              0.38         0.28             2.1      0.066
# 89              8.0              0.59         0.16             1.8      0.065
# ...             ...               ...          ...             ...        ...
# 1096            6.6              0.56         0.14             2.4      0.064
# 1100            8.4              0.37         0.43             2.3      0.063
# 1104            7.4              0.36         0.30             1.8      0.074
# 1108            7.0              0.56         0.17             1.7      0.065
# 1133            6.7              0.32         0.44             2.4      0.061
#
# ...

# %%
# Grouping and aggregating
mean_quality_by_acidity = df.groupby('fixed acidity')['quality'].mean()
mean_quality_by_acidity
# Out:
# fixed acidity
# 4.6     4.000000
# 4.9     7.000000
# 5.0     5.833333
# 5.1     6.750000
# 5.2     6.000000
#           ...
# 14.3    6.000000
# 15.0    7.000000
# 15.5    5.000000
# 15.6    6.000000
# 15.9    5.000000
# Name: quality, Length: 91, dtype: float64

# %%
# Convert a column to a NumPy array
alcohol_array = df['alcohol'].values
alcohol_array
# Out:
# array([ 9.4,  9.8,  9.8, ..., 10.5, 11.2, 10.2])

# %%
# Perform calculations
mean_alcohol = np.mean(alcohol_array)
mean_alcohol
# Out:
# np.float64(10.442111402741034)

# %% [markdown]
# # Distribution of Alcohol Content

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['alcohol'], bins=30, kde=True)
plt.title('Distribution of Alcohol Content')
plt.xlabel('Alcohol Content')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Distribution of Wine Quality Ratings

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Distribution of wine quality
plt.figure(figsize=(8, 6))
sns.countplot(x='quality', data=df)
plt.title('Distribution of Wine Quality Ratings')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='density', y='alcohol', hue='quality', palette='viridis', data=df, s=100)
plt.title('Density vs. Alcohol Content by Wine Quality')
plt.xlabel('Density')
plt.ylabel('Alcohol Content')
plt.show()

# %% [markdown]
# # Volatile Acidity

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['volatile acidity'], bins=30, color='cyan', edgecolor='black')
plt.title('Distribution of Volatile Acidity')
plt.xlabel('Volatile Acidity')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # Distribution of Density

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['density'], bins=30, color='purple', edgecolor='black')
plt.title('Distribution of Density')
plt.xlabel('Density')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # Scatter Plot: Volatile Acidity vs. Wine Quality

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['volatile acidity'], df['quality'], alpha=0.5, color='red')
plt.title('Volatile Acidity vs. Wine Quality')
plt.xlabel('Volatile Acidity')
plt.ylabel('Quality')
plt.grid(True)
plt.show()
